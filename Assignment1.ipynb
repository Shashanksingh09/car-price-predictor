# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Pre-Owned Car Resale in India-2021.csv")
df=df.rename(columns={'distance_covered (km)':'distance_covered'})
df
# Out:
#       model_year    maker        model_name     city  distance_covered  \
# 0           2012   Maruti      Alto K10 VXI   Mumbai             29067
# 1           2011  Hyundai  i20 SPORTZ 1.2 O   Mumbai             36791
# 2           2010   Maruti        A Star VXI   Mumbai             35171
# 3           2011  Hyundai   Santro Xing GLS   Mumbai             19908
# 4           2012  Hyundai   Santro Xing GLS   Mumbai             43847
# ...          ...      ...               ...      ...               ...
# 3360        2014    Honda  City S MT DIESEL  Kolkata             61643
# 3361        2006   Maruti       Wagon R LXI  Kolkata             26500
# 3362        2016   Maruti  S Cross ZETA 1.3  Kolkata             57828
# 3363        2012      BMW     3 Series 320D  Kolkata             23782
# 3364        2016  Hyundai    Creta 1.4 BASE  Kolkata             33130
#
#      fuel_type  pre_owner  price (₹)
# 0       Petrol  2nd Owner     165199
# 1       Petrol  2nd Owner     326099
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score

# %%
x=df[['model_year','maker','distance_covered','fuel_type','pre_owner']]
y=df['price (₹)']

# %%
df
# Out:
#       model_year    maker        model_name     city  distance_covered  \
# 0           2012   Maruti      Alto K10 VXI   Mumbai             29067
# 1           2011  Hyundai  i20 SPORTZ 1.2 O   Mumbai             36791
# 2           2010   Maruti        A Star VXI   Mumbai             35171
# 3           2011  Hyundai   Santro Xing GLS   Mumbai             19908
# 4           2012  Hyundai   Santro Xing GLS   Mumbai             43847
# ...          ...      ...               ...      ...               ...
# 3360        2014    Honda  City S MT DIESEL  Kolkata             61643
# 3361        2006   Maruti       Wagon R LXI  Kolkata             26500
# 3362        2016   Maruti  S Cross ZETA 1.3  Kolkata             57828
# 3363        2012      BMW     3 Series 320D  Kolkata             23782
# 3364        2016  Hyundai    Creta 1.4 BASE  Kolkata             33130
#
#      fuel_type  pre_owner  price (₹)
# 0       Petrol  2nd Owner     165199
# 1       Petrol  2nd Owner     326099
# ...

# %%
x=pd.get_dummies(x,columns=['maker','fuel_type','pre_owner'])

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
x_train.columns
# Out:
# Index(['model_year', 'distance_covered', 'maker_Audi', 'maker_BMW',
#        'maker_Chevrolet', 'maker_Datsun', 'maker_Fiat', 'maker_Ford',
#        'maker_Honda', 'maker_Hyundai', 'maker_Jeep', 'maker_KIA', 'maker_MG',
#        'maker_Mahindra', 'maker_Maruti', 'maker_Mercedes', 'maker_Nissan',
#        'maker_Renault', 'maker_Skoda', 'maker_Ssangyong', 'maker_Tata',
#        'maker_Toyota', 'maker_Volkswagen', 'maker_Volvo', 'fuel_type_Diesel',
#        'fuel_type_Electric', 'fuel_type_Petrol', 'fuel_type_Petrol + CNG',
#        'fuel_type_Petrol + LPG', 'pre_owner_1st Owner', 'pre_owner_2nd Owner',
#        'pre_owner_3rd Owner', 'pre_owner_4th Owner', 'pre_owner_6th Owner'],
#       dtype='object')

# %%
model=LinearRegression()
model.fit(x_train, y_train)

y_pred=model.predict(x_test)
print(y_pred)
# Out:
# [ 466438.04045217  449328.82582186  765262.99447     653235.11658697
#   446770.46219641  474543.37602982  487168.17040639  485167.60750642
#   205109.71358185  227787.34948428  316994.79289047  530126.16997035
#   408685.00803088  445321.50728735  335172.92373396  530862.12348863
#   811406.31568326  276765.83669728  423138.09872817  399229.6241708
#   212558.87027606  265112.44355047  589972.07027628  599827.8073303
#   557397.59069121  526769.08856477  576107.3063505   595648.36853585
#   512387.05374119 1572069.13777499  254476.34937868  429113.75960298
#   447845.7273407   356139.7394222   683487.69004539  207769.47473589
#   666076.213       488163.65248708  579318.19608796  212723.90655296
#   250216.38561404  601097.16885236  190350.29031475  270906.05636913
#   121747.18533795  445456.05291931  766754.72101353  388873.33838892
#   331926.6145238   572549.32369272  352332.29211605  601515.38622622
#   247389.9183481   297116.95881212  481178.24790215  745136.34649876
# ...

# %%
import joblib

joblib.dump(model,'Assignment1.pkl')
# Out:
# ['Assignment1.pkl']
